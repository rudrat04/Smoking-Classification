# %%
import numpy as np
import pandas as pd
import plotly.express as px

# %%
smoking = pd.read_csv('smoking_cleaned.csv')

# %%
smoking.head()
# Out:
#    gender  age marital_status highest_qualification nationality ethnicity  \
# 0    Male   38       Divorced      No Qualification     British     White
# 1  Female   42         Single      No Qualification     British     White
# 2    Male   40        Married                Degree     English     White
# 3  Female   40        Married                Degree     English     White
# 4  Female   39        Married          GCSE/O Level     British     White
#
#       region  avg_salary smoke
# 0  The North      3900.0    No
# 1  The North      1300.0   Yes
# 2  The North     32500.0    No
# 3  The North     13000.0    No
# 4  The North      3900.0    No

# %%
from autogluon.tabular import TabularPredictor, TabularDataset

# %%
X = smoking.drop('smoke', axis=1)
y = smoking['smoke']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 45)

# %%
save_path = 'agModels-predictClass'  # specifies folder to store trained models
predictor = TabularPredictor(label='smoke', path=save_path).fit(smoking)
# Out:
# Warning: path already exists! This predictor may overwrite an existing predictor! path="agModels-predictClass"
# No presets specified! To achieve strong results with AutoGluon, it is recommended to use the available presets.
# 	Recommended Presets (For more details refer to https://auto.gluon.ai/stable/tutorials/tabular/tabular-essentials.html#presets):
# 	presets='best_quality'   : Maximize accuracy. Default time_limit=3600.
# 	presets='high_quality'   : Strong accuracy with fast inference speed. Default time_limit=3600.
# 	presets='good_quality'   : Good accuracy with very fast inference speed. Default time_limit=3600.
# 	presets='medium_quality' : Fast training time, ideal for initial prototyping.
# Beginning AutoGluon training ...
# AutoGluon will save models to "agModels-predictClass"
# =================== System Info ===================
# AutoGluon Version:  1.0.0
# Python Version:     3.11.8
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.22635
# CPU Count:          8
# Memory Avail:       8.93 GB / 15.84 GB (56.4%)
# Disk Space Avail:   778.06 GB / 931.51 GB (83.5%)
# ===================================================
# Train Data Rows:    1691
# Train Data Columns: 8
# Label Column:       smoke
# AutoGluon infers your prediction problem is: 'binary' (because only two unique label-values observed).
# 	2 unique label values:  ['No', 'Yes']
# 	If 'binary' is not the correct problem_type, please manually specify the problem_type parameter during predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Problem Type:       binary
# Preprocessing data ...
# Selected class <--> label mapping:  class 1 = Yes, class 0 = No
# 	Note: For your binary classification, AutoGluon arbitrarily selected which label-value represents positive (Yes) vs negative (No) class.
# 	To explicitly set the positive_class, either rename classes to 1 and 0, or specify positive_class in Predictor init.
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    9137.64 MB
# 	Train Data (Original)  Memory Usage: 0.65 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 1 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', [])  : 1 | ['avg_salary']
# 		('int', [])    : 1 | ['age']
# 		('object', []) : 6 | ['gender', 'marital_status', 'highest_qualification', 'nationality', 'ethnicity', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', [])  : 5 | ['marital_status', 'highest_qualification', 'nationality', 'ethnicity', 'region']
# 		('float', [])     : 1 | ['avg_salary']
# 		('int', [])       : 1 | ['age']
# 		('int', ['bool']) : 1 | ['gender']
# 	0.1s = Fit runtime
# 	8 features in original data used to generate 8 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.04 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.12s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# 	To change this, specify the eval_metric parameter of Predictor()
# Automatically generating train/validation split with holdout_frac=0.2, Train Rows: 1352, Val Rows: 339
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': {},
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': {},
# 	'XGB': {},
# 	'FASTAI': {},
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# Fitting 13 L1 models ...
# Fitting model: KNeighborsUnif ...
# 	0.7581	 = Validation score   (accuracy)
# 	2.56s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: KNeighborsDist ...
# 	0.7286	 = Validation score   (accuracy)
# 	0.01s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: LightGBMXT ...
# C:\Users\Rudra\miniconda3\envs\myenv\Lib\site-packages\dask\dataframe\__init__.py:31: FutureWarning:
# Dask dataframe query planning is disabled because dask-expr is not installed.
#
# You can install it with `pip install dask[dataframe]` or `conda install dask`.
# This will raise in a future version.
#
#   warnings.warn(msg, FutureWarning)
# 	0.764	 = Validation score   (accuracy)
# 	1.05s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: LightGBM ...
# 	0.7906	 = Validation score   (accuracy)
# 	0.39s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: RandomForestGini ...
# 	0.7227	 = Validation score   (accuracy)
# 	0.65s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: RandomForestEntr ...
# 	0.7227	 = Validation score   (accuracy)
# 	0.66s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: CatBoost ...
# 	0.7729	 = Validation score   (accuracy)
# 	8.63s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: ExtraTreesGini ...
# 	0.7375	 = Validation score   (accuracy)
# 	0.53s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: ExtraTreesEntr ...
# 	0.7434	 = Validation score   (accuracy)
# 	0.47s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: NeuralNetFastAI ...
# No improvement since epoch 8: early stopping
# 	0.764	 = Validation score   (accuracy)
# 	3.93s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: XGBoost ...
# 	0.767	 = Validation score   (accuracy)
# 	1.0s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: NeuralNetTorch ...
# 	0.764	 = Validation score   (accuracy)
# 	7.57s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: LightGBMLarge ...
# 	0.7581	 = Validation score   (accuracy)
# 	0.48s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ...
# 	Ensemble Weights: {'LightGBM': 1.0}
# 	0.7906	 = Validation score   (accuracy)
# 	0.63s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 30.25s ... Best model: "WeightedEnsemble_L2"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("agModels-predictClass")

# %%
predictor = TabularPredictor.load("agModels-predictClass")

# %%
predictor

# %%
test_data = smoking.sample(100)
y_test = test_data['smoke']  # values to predict
test_data_nolab = test_data.drop(columns=['smoke'])  # delete label column to prove we're not cheating
test_data_nolab.head()
# Out:
#       gender  age marital_status highest_qualification nationality ethnicity  \
# 124   Female   52        Married     Higher/Sub Degree     British     White
# 1687  Female   49       Divorced      Other/Sub Degree     English     White
# 1380  Female   33        Married                Degree     British     Asian
# 6       Male   53        Married                Degree     British     White
# 1422  Female   43        Married              GCSE/CSE     English     White
#
#           region  avg_salary
# 124    The North     18200.0
# 1687    Scotland      3900.0
# 1380  South West      7800.0
# 6      The North     18200.0
# 1422  South West      3900.0

# %%
predictor = TabularPredictor.load(save_path)  # unnecessary, just demonstrates how to load previously-trained predictor from file

y_pred = predictor.predict(test_data_nolab)
print("Predictions:  \n", y_pred)
perf = predictor.evaluate_predictions( y_pred=y_pred, auxiliary_metrics=True, detailed_report=True, display=True)
# Out:
# Predictions:
#  124      No
# 1687    Yes
# 1380     No
# 6        No
# 1422     No
#        ...
# 760      No
# 942      No
# 1164     No
# 1025     No
# 871      No
# Name: smoke, Length: 100, dtype: object
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[70], line 5
#       3 y_pred = predictor.predict(test_data_nolab)
#       4 print("Predictions:  \n", y_pred)
# ----> 5 perf = predictor.evaluate_predictions( y_pred=y_pred, auxiliary_metrics=True, detailed_report=True, display=True)
#
# TypeError: TabularPredictor.evaluate_predictions() missing 1 required positional argument: 'y_true'

# %%
perf
# Out:
# {'accuracy': 0.81,
#  'balanced_accuracy': 0.6022021456804065,
#  'mcc': 0.36220941758254493,
#  'f1': 0.3448275862068966,
#  'precision': 0.8333333333333334,
#  'recall': 0.21739130434782608,
#  'confusion_matrix':      No  Yes
#  No   76    1
#  Yes  18    5,
#  'classification_report': {'No': {'precision': 0.8085106382978723,
#    'recall': 0.987012987012987,
#    'f1-score': 0.8888888888888888,
#    'support': 77.0},
#   'Yes': {'precision': 0.8333333333333334,
#    'recall': 0.21739130434782608,
#    'f1-score': 0.3448275862068966,
#    'support': 23.0},
#   'accuracy': 0.81,
#   'macro avg': {'precision': 0.8209219858156028,
#    'recall': 0.6022021456804065,
#    'f1-score': 0.6168582375478927,
#    'support': 100.0},
#   'weighted avg': {'precision': 0.8142198581560284,
#    'recall': 0.81,
#    'f1-score': 0.7637547892720307,
#    'support': 100.0}}}

# %%
test_data.tail()
# Out:
#       gender  age marital_status highest_qualification nationality ethnicity  \
# 760   Female   30         Single              ONC/BTEC     British     White
# 942     Male   66        Married                Degree     British     Asian
# 1164  Female   36        Married              GCSE/CSE     British     White
# 1025    Male   28         Single          GCSE/O Level     Refused   Refused
# 871     Male   40        Married                Degree       Welsh     White
#
#                       region  avg_salary smoke
# 760   Midlands & East Anglia     18200.0    No
# 942                   London     13000.0   Yes
# 1164              South East      1300.0    No
# 1025                  London         0.0    No
# 871                   London     18200.0    No

# %%
column = ['gender', 'age', 'marital_status', 'highest_qualification', 'nationality', 'ethnicity', 'region', 'avg_salary']

# %%
new_data = ['Female', 30, 'Single', 'Degree', 'Welsh', 'White', 'London', 1500]
df1 = pd.DataFrame([new_data], columns = column)

# %%
df1
# Out:
#    gender  age marital_status highest_qualification nationality ethnicity  \
# 0  Female   30         Single                Degree       Welsh     White
#
#    region  avg_salary
# 0  London        1500

# %%
y = predictor.predict(df1)
y
# Out:
# 0    No
# Name: smoke, dtype: object

# %%
predictor.feature_importance(data = smoking)
# Out:
# Computing feature importance via permutation shuffling for 8 features using 1691 rows with 5 shuffle sets...
# 	0.79s	= Expected runtime (0.16s per shuffle set)
# 	0.27s	= Actual runtime (Completed 5 of 5 shuffle sets)
#                        importance    stddev   p_value  n  p99_high   p99_low
# age                      0.068007  0.004562  0.000002  5  0.077399  0.058615
# marital_status           0.032762  0.004002  0.000026  5  0.041002  0.024521
# highest_qualification    0.025547  0.003407  0.000037  5  0.032563  0.018531
# avg_salary               0.024601  0.005923  0.000374  5  0.036795  0.012406
# region                   0.018096  0.003846  0.000231  5  0.026015  0.010177
# gender                   0.009817  0.002495  0.000460  5  0.014954  0.004679
# nationality              0.001301  0.001794  0.090076  5  0.004994 -0.002392
# ethnicity                0.000000  0.000000  0.500000  5  0.000000  0.000000

# %%
predictor.evaluate_predictions(y_true= df1, y_pred=y, auxiliary_metrics=True, detailed_report=True, display=True)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 predictor.evaluate_predictions(y_true= df1, y_pred=y, auxiliary_metrics=True, detailed_report=True, display=True)
#
# File ~\miniconda3\envs\myenv\Lib\site-packages\autogluon\tabular\predictor\predictor.py:2144, in TabularPredictor.evaluate_predictions(self, y_true, y_pred, sample_weight, decision_threshold, display, auxiliary_metrics, detailed_report, **kwargs)
#    2142 if decision_threshold is None:
#    2143     decision_threshold = self.decision_threshold
# -> 2144 return self._learner.evaluate_predictions(
#    2145     y_true=y_true,
#    2146     y_pred=y_pred,
#    2147     sample_weight=sample_weight,
#    2148     decision_threshold=decision_threshold,
#    2149     display=display,
#    2150     auxiliary_metrics=auxiliary_metrics,
#    2151     detailed_report=detailed_report,
#    2152 )
#
# File ~\miniconda3\envs\myenv\Lib\site-packages\autogluon\tabular\learner\abstract_learner.py:702, in AbstractTabularLearner.evaluate_predictions(self, y_true, y_pred, sample_weight, decision_threshold, display, auxiliary_metrics, detailed_report)
#     691 """Evaluate predictions. Does not support sample weights since this method reports a variety of metrics.
#     692 Args:
#     693     display (bool): Should we print which metric is being used as well as performance.
#    (...)
#     698 Otherwise returns dict where keys = metrics, values = performance along each metric.
#     699 """
#     701 is_proba = False
# --> 702 assert isinstance(y_true, (np.ndarray, pd.Series))
#     703 assert isinstance(y_pred, (np.ndarray, pd.Series, pd.DataFrame))
#     704 self._validate_class_labels(y_true)
#
# AssertionError:

# %%
predictor.leaderboard(display=True)
# Out:
#                   model  score_val eval_metric  pred_time_val  fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0   WeightedEnsemble_L2   0.790560    accuracy       0.000000  1.016823                0.000000           0.627726            2       True         14
# 1              LightGBM   0.790560    accuracy       0.000000  0.389097                0.000000           0.389097            1       True          4
# 2              CatBoost   0.772861    accuracy       0.000000  8.628204                0.000000           8.628204            1       True          7
# 3               XGBoost   0.766962    accuracy       0.015621  0.996014                0.015621           0.996014            1       True         11
# 4            LightGBMXT   0.764012    accuracy       0.000000  1.047141                0.000000           1.047141            1       True          3
# 5        NeuralNetTorch   0.764012    accuracy       0.013366  7.574719                0.013366           7.574719            1       True         12
# 6       NeuralNetFastAI   0.764012    accuracy       0.021815  3.934528                0.021815           3.934528            1       True         10
# 7         LightGBMLarge   0.758112    accuracy       0.015621  0.478631                0.015621           0.478631            1       True         13
# 8        KNeighborsUnif   0.758112    accuracy       0.021710  2.560985                0.021710           2.560985            1       True          1
# 9        ExtraTreesEntr   0.743363    accuracy       0.036534  0.474351                0.036534           0.474351            1       True          9
# 10       ExtraTreesGini   0.737463    accuracy       0.045891  0.526917                0.045891           0.526917            1       True          8
# 11       KNeighborsDist   0.728614    accuracy       0.014923  0.005212                0.014923           0.005212            1       True          2
# 12     RandomForestGini   0.722714    accuracy       0.045641  0.651090                0.045641           0.651090            1       True          5
# 13     RandomForestEntr   0.722714    accuracy       0.048699  0.655128                0.048699           0.655128            1       True          6
#                   model  score_val eval_metric  pred_time_val  fit_time  \
# 0   WeightedEnsemble_L2   0.790560    accuracy       0.000000  1.016823
# 1              LightGBM   0.790560    accuracy       0.000000  0.389097
# 2              CatBoost   0.772861    accuracy       0.000000  8.628204
# 3               XGBoost   0.766962    accuracy       0.015621  0.996014
# 4            LightGBMXT   0.764012    accuracy       0.000000  1.047141
# 5        NeuralNetTorch   0.764012    accuracy       0.013366  7.574719
# 6       NeuralNetFastAI   0.764012    accuracy       0.021815  3.934528
# 7         LightGBMLarge   0.758112    accuracy       0.015621  0.478631
# 8        KNeighborsUnif   0.758112    accuracy       0.021710  2.560985
# 9        ExtraTreesEntr   0.743363    accuracy       0.036534  0.474351
# 10       ExtraTreesGini   0.737463    accuracy       0.045891  0.526917
# 11       KNeighborsDist   0.728614    accuracy       0.014923  0.005212
# 12     RandomForestGini   0.722714    accuracy       0.045641  0.651090
# 13     RandomForestEntr   0.722714    accuracy       0.048699  0.655128
#
#     pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 0                 0.000000           0.627726            2       True
# 1                 0.000000           0.389097            1       True
# 2                 0.000000           8.628204            1       True
# 3                 0.015621           0.996014            1       True
# 4                 0.000000           1.047141            1       True
# 5                 0.013366           7.574719            1       True
# 6                 0.021815           3.934528            1       True
# 7                 0.015621           0.478631            1       True
# 8                 0.021710           2.560985            1       True
# 9                 0.036534           0.474351            1       True
# 10                0.045891           0.526917            1       True
# 11                0.014923           0.005212            1       True
# 12                0.045641           0.651090            1       True
# 13                0.048699           0.655128            1       True
#
#     fit_order
# 0          14
# 1           4
# 2           7
# 3          11
# 4           3
# 5          12
# 6          10
# 7          13
# 8           1
# 9           9
# 10          8
# 11          2
# 12          5
# 13          6
